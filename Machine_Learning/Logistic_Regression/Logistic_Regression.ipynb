# %% [markdown]
# <h2>Aim: To predict if a person haas AHD or not</h2>

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gjrah\Documents\Data Science\Meta_Scifor\Data Sets\Heart.csv")

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %% [markdown]
# <h3>Data Pre-Processing</h3>

# %%
#Dropping Unamed: 0 since it has not relavance with our analysis
df = df.drop(columns = "Unnamed: 0")

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df['ChestPain'] = df['ChestPain'].astype('category')
df['ChestPain'] = df['ChestPain'].cat.codes

# %%
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca        Thal  AHD
# ...

# %% [markdown]
# <b>Categorical Data to Cat Code</b> <br>
# asymptomatic = 0 <br>
# nonanginal = 1 <br>
# nontypical = 2 <br>
# typical = 3

# %%
df['Thal'] = df['Thal'].astype("category")
df['Thal'] = df['Thal'].cat.codes

# %%
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0   No
# ...

# %% [markdown]
# <b> Categorical to CatCode </b>
# * Fixed = 0
# * Normal = 1
# * Reversable = 2

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         0
# AHD          0
# dtype: int64

# %% [markdown]
# * We have 4 <b>null values</b> in Ca

# %%
df.dropna()
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 297   57    0          0     140   241    0        0    123      1      0.2
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0   No
# ...

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         0
# AHD          0
# dtype: int64

# %% [markdown]
# * We have dropped the null values
# * It has affected our dataset from 303 rows to 299 rows

# %% [markdown]
# <h2>Preparing For Logistic Regression</h2>

# %%
X = df.drop(columns="AHD")
X
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal
# 0        3  0.0     0
# ...

# %%
Y = df['AHD']
Y
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3       No
# 4       No
#       ...
# 298    Yes
# 299    Yes
# 300    Yes
# 301    Yes
# 302     No
# Name: AHD, Length: 303, dtype: object

# %% [markdown]
# * Train on X parameter to predict Y

# %% [markdown]
# <h2> Logistic Regression </h2>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=23)

# %%
print("X_train \n")
print(X_train)
print("\n")
print("X_test \n")
print(X_test)
# Out:
# X_train
#
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 163   58    0          0     100   248    0        2    122      0      1.0
# 260   44    0          1     118   242    0        0    149      0      0.3
# 124   65    1          3     138   282    1        2    174      0      1.4
# 110   61    0          0     145   307    0        2    146      1      1.0
# 13    44    1          2     120   263    0        0    173      0      0.0
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 237   46    1          0     120   249    0        2    144      0      0.8
# 31    60    1          0     117   230    1        0    160      1      1.4
# 40    65    0          0     150   225    0        2    114      0      1.0
# 230   52    0          1     136   196    0        2    169      0      0.1
# 83    68    1          1     180   274    1        2    150      1      1.6
#
#      Slope   Ca  Thal
# ...

# %% [markdown]
# * We can see that X_train has 70% of the dataset while X_test has 30%

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.39538635, -1.42427927, -0.88829631, ...,  0.60745674,
#         -0.6831588 , -0.51503427],
#        [-1.1366067 , -1.42427927,  0.12417045, ...,  0.60745674,
#          0.3985093 , -0.51503427],
#        [ 1.16138287,  0.7021095 ,  2.14910398, ...,  0.60745674,
#          0.3985093 , -0.51503427],
#        ...,
#        [ 1.16138287, -1.42427927, -0.88829631, ...,  0.60745674,
#          2.56184552,  1.1146264 ],
#        [-0.2611821 , -1.42427927,  0.12417045, ...,  0.60745674,
#         -0.6831588 , -0.51503427],
#        [ 1.48966709,  0.7021095 ,  0.12417045, ...,  0.60745674,
#         -0.6831588 ,  1.1146264 ]])

# %%
X_test_scaled
# Out:
# array([[ 0.06710212, -1.42427927, -0.88829631, ...,  0.60745674,
#         -0.6831588 , -0.51503427],
#        [-0.37061018,  0.7021095 ,  0.12417045, ..., -1.00230362,
#         -0.6831588 , -0.51503427],
#        [ 1.38023902,  0.7021095 , -0.88829631, ...,  0.60745674,
#          1.48017741,  1.1146264 ],
#        ...,
#        [-0.48003825,  0.7021095 , -0.88829631, ...,  0.60745674,
#         -0.6831588 ,  1.1146264 ],
#        [-0.04232595,  0.7021095 , -0.88829631, ...,  0.60745674,
#          0.3985093 ,  1.1146264 ],
#        [ 1.05195479,  0.7021095 , -0.88829631, ...,  0.60745674,
#          0.3985093 ,  1.1146264 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(random_state=0).fit(X_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 log_reg = LogisticRegression(random_state=0).fit(X_train_scaled,y_train)
#
# File C:\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File C:\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1223, in LogisticRegression.fit(self, X, y, sample_weight)
#    1220 else:
#    1221     _dtype = [np.float64, np.float32]
# -> 1223 X, y = self._validate_data(
#    1224     X,
#    1225     y,
#    1226     accept_sparse="csr",
# ...

# %% [markdown]
# <b>Resolving the Null Issue. </b>

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled)

# %%
X_train_scaled_df = X_train_scaled_df.dropna()

# %%
X_train_scaled = X_train_scaled.to_numpy()

# %% [markdown]
# * The above method, didn't resolve our issue, therefore I decided to use Imputer

# %%
# Impute missing values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_train_scaled_imputed = imputer.fit_transform(X_train_scaled)
X_test_scaled_imputed = imputer.transform(X_test_scaled)

# %%
log_reg = LogisticRegression(random_state=0).fit(X_train_scaled_imputed, y_train)

# %%
log_reg.predict(X_train_scaled_imputed)
# Out:
# array(['No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes',
#        'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes',
#        'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
#        'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
# ...

# %%
#Predicted the accuracy for train attributes

# %%
log_reg.score(X_train_scaled_imputed, y_train)
# Out:
# 0.8632075471698113

# %%
#Predicted the accuracy for test attributes

# %%
log_reg.score(X_test_scaled_imputed, y_test)
# Out:
# 0.8021978021978022

# %% [markdown]
# <b> Imporving the model </b>

# %% [markdown]
# * I added the C intercept
# * <b> C = 0.1 </b> gives better results

# %%
log_reg1 = LogisticRegression(
    random_state=0,
    C=0.1,
    fit_intercept=True,
).fit(X_train_scaled_imputed,y_train)

# %%
log_reg1.score(X_test_scaled_imputed, y_test)
# Out:
# 0.8131868131868132
